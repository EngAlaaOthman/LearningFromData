# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# Define sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def plot_decision_boundary(w, iteration):
    # Create grid matrix with bias term
    grid = np.c_[np.ones(xx1.ravel().shape[0]), xx1.ravel(), xx2.ravel()]
    
    # Calculate predictions using the current model
    Z = np.sign(grid @ w)
    Z = Z.reshape(xx1.shape)

    # Plot decision boundary with region coloring
    plt.figure(figsize=(8, 6))
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=ListedColormap(('#FFAAAA', '#AAAAFF')))
    plt.contour(xx1, xx2, Z, levels=[0], linewidths=2, colors='black', label='Decision Boundary')
    
    # Plot data points
    plt.scatter(X[:,1], X[:,2], c=y, cmap=ListedColormap(('red', 'blue')), s=150, edgecolors='k', label='Data Points')
    plt.scatter(test_point1[1], test_point1[2], c='purple', marker='x', s=250, linewidths=2, label='Test Point 1')
    plt.scatter(test_point2[1], test_point2[2], c='orange', marker='X', s=250, linewidths=2, label='Test Point 2')
    
    # Formatting
    plt.xlim(x1_min, x1_max)
    plt.ylim(x2_min, x2_max)
    plt.title(f"Iteration {iteration}\nWeights: {w.round(4)}")
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.legend(loc='upper right')
    plt.grid(True)
    plt.show()

# %%
# Data setup with bias term (x0=1)
X = np.array([[1, 1, 1],  # x1
             [1, 3, 3]]) # x2
y = np.array([1, -1])

# Test points with bias term
test_point1 = np.array([1, 3, 4])
test_point2 = np.array([1, 0, 1])

# Initialize weights
w = np.zeros(3)
eta = 0.5
n_iterations = 20

# %%
# Create grid for visualization
x1_min, x1_max = -1, 5
x2_min, x2_max = -1, 5
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max, 200),
                       np.linspace(x2_min, x2_max, 200))
# Perform multiple iterations of gradient descent
for iteration in range(n_iterations):
    print(f"\n=== Iteration {iteration + 1} ===")
    print(f"Current weights: {w.round(4)}")
    
    # 1. Compute scores
    scores = X @ w
    print(f"Scores: {scores.round(4)}")
    
    # 2. Compute sigmoid activations
    sigmoid_terms = sigmoid(-y * scores)
    print(f"Sigmoid terms: {sigmoid_terms.round(4)}")
    
    # 3. Compute gradient
    gradient = -(1 / len(X)) * (X.T @ (y * sigmoid_terms))
    print(f"Gradient: {gradient.round(4)}")
    
    # 4. Update weights
    w -= eta * gradient
    print(f"Updated weights: {w.round(4)}")
    
    # 5. Predict test points
    test_score1 = test_point1 @ w
    test_prob1 = sigmoid(test_score1)
    test_score2 = test_point2 @ w
    test_prob2 = sigmoid(test_score2)
    
    print(f"Test Point 1 Probability (class -1): {test_prob1.round(4)} {'(Misclassified)' if test_prob1 > 0.5 else '(Correct)'}")
    print(f"Test Point 2 Probability (class +1): {test_prob2.round(4)} {'(Misclassified)' if test_prob2 < 0.5 else '(Correct)'}")
    
    # Visualize decision boundary every few iterations
    if iteration % 2 == 0 or iteration == n_iterations - 1:
        plot_decision_boundary(w, iteration+1)
# Out:
# === Iteration 1 ===
# Current weights: [0. 0. 0.]
# Scores: [0. 0.]
# Sigmoid terms: [0.5 0.5]
# Gradient: [-0.   0.5  0.5]
# Updated weights: [ 0.   -0.25 -0.25]
# Test Point 1 Probability (class -1): 0.148 (Correct)
# Test Point 2 Probability (class +1): 0.4378 (Misclassified)
# C:\Users\engal\AppData\Local\Temp\ipykernel_30064\707665989.py:16: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx1, xx2, Z, levels=[0], linewidths=2, colors='black', label='Decision Boundary')
# === Iteration 2 ===
# Current weights: [ 0.   -0.25 -0.25]
# Scores: [-0.5 -1.5]
# Sigmoid terms: [0.6225 0.1824]
# Gradient: [-0.22   -0.0376 -0.0376]
# Updated weights: [ 0.11   -0.2312 -0.2312]
# Test Point 1 Probability (class -1): 0.1812 (Correct)
# Test Point 2 Probability (class +1): 0.4697 (Misclassified)
#
# === Iteration 3 ===
# Current weights: [ 0.11   -0.2312 -0.2312]
# Scores: [-0.3524 -1.2772]
# Sigmoid terms: [0.5872 0.218 ]
# Gradient: [-0.1846  0.0334  0.0334]
# Updated weights: [ 0.2023 -0.2479 -0.2479]
# Test Point 1 Probability (class -1): 0.1775 (Correct)
# Test Point 2 Probability (class +1): 0.4886 (Misclassified)
# === Iteration 4 ===
# Current weights: [ 0.2023 -0.2479 -0.2479]
# Scores: [-0.2935 -1.2852]
# Sigmoid terms: [0.5729 0.2167]
# Gradient: [-0.1781  0.0386  0.0386]
# Updated weights: [ 0.2914 -0.2672 -0.2672]
# Test Point 1 Probability (class -1): 0.1709 (Correct)
# Test Point 2 Probability (class +1): 0.506 (Correct)
#
# === Iteration 5 ===
# Current weights: [ 0.2914 -0.2672 -0.2672]
# Scores: [-0.2431 -1.3119]
# Sigmoid terms: [0.5605 0.2122]
# Gradient: [-0.1741  0.038   0.038 ]
# Updated weights: [ 0.3784 -0.2862 -0.2862]
# Test Point 1 Probability (class -1): 0.1645 (Correct)
# Test Point 2 Probability (class +1): 0.523 (Correct)
# === Iteration 6 ===
# Current weights: [ 0.3784 -0.2862 -0.2862]
# Scores: [-0.194  -1.3389]
# Sigmoid terms: [0.5484 0.2077]
# Gradient: [-0.1703  0.0374  0.0374]
# Updated weights: [ 0.4636 -0.3049 -0.3049]
# Test Point 1 Probability (class -1): 0.1583 (Correct)
# Test Point 2 Probability (class +1): 0.5396 (Correct)
#
# === Iteration 7 ===
# Current weights: [ 0.4636 -0.3049 -0.3049]
# Scores: [-0.1462 -1.3658]
# Sigmoid terms: [0.5365 0.2033]
# Gradient: [-0.1666  0.0367  0.0367]
# Updated weights: [ 0.5469 -0.3233 -0.3233]
# Test Point 1 Probability (class -1): 0.1524 (Correct)
# Test Point 2 Probability (class +1): 0.5557 (Correct)
# === Iteration 8 ===
# Current weights: [ 0.5469 -0.3233 -0.3233]
# Scores: [-0.0996 -1.3926]
# Sigmoid terms: [0.5249 0.199 ]
# Gradient: [-0.1629  0.036   0.036 ]
# Updated weights: [ 0.6284 -0.3413 -0.3413]
# Test Point 1 Probability (class -1): 0.1467 (Correct)
# Test Point 2 Probability (class +1): 0.5713 (Correct)
#
# === Iteration 9 ===
# Current weights: [ 0.6284 -0.3413 -0.3413]
# Scores: [-0.0542 -1.4193]
# Sigmoid terms: [0.5135 0.1948]
# Gradient: [-0.1594  0.0354  0.0354]
# Updated weights: [ 0.7081 -0.359  -0.359 ]
# Test Point 1 Probability (class -1): 0.1413 (Correct)
# Test Point 2 Probability (class +1): 0.5864 (Correct)
# === Iteration 10 ===
# Current weights: [ 0.7081 -0.359  -0.359 ]
# Scores: [-0.0099 -1.4458]
# Sigmoid terms: [0.5025 0.1907]
# Gradient: [-0.1559  0.0347  0.0347]
# Updated weights: [ 0.786  -0.3763 -0.3763]
# Test Point 1 Probability (class -1): 0.1361 (Correct)
# Test Point 2 Probability (class +1): 0.601 (Correct)
#
# === Iteration 11 ===
# Current weights: [ 0.786  -0.3763 -0.3763]
# Scores: [ 0.0333 -1.472 ]
# Sigmoid terms: [0.4917 0.1866]
# Gradient: [-0.1525  0.0341  0.0341]
# Updated weights: [ 0.8623 -0.3934 -0.3934]
# Test Point 1 Probability (class -1): 0.1311 (Correct)
# Test Point 2 Probability (class +1): 0.6151 (Correct)
# === Iteration 12 ===
# Current weights: [ 0.8623 -0.3934 -0.3934]
# Scores: [ 0.0755 -1.4981]
# Sigmoid terms: [0.4811 0.1827]
# Gradient: [-0.1492  0.0335  0.0335]
# Updated weights: [ 0.9369 -0.4101 -0.4101]
# Test Point 1 Probability (class -1): 0.1263 (Correct)
# Test Point 2 Probability (class +1): 0.6287 (Correct)
#
# === Iteration 13 ===
# Current weights: [ 0.9369 -0.4101 -0.4101]
# Scores: [ 0.1166 -1.524 ]
# Sigmoid terms: [0.4709 0.1789]
# Gradient: [-0.146   0.0329  0.0329]
# Updated weights: [ 1.0099 -0.4266 -0.4266]
# Test Point 1 Probability (class -1): 0.1217 (Correct)
# Test Point 2 Probability (class +1): 0.6418 (Correct)
# === Iteration 14 ===
# Current weights: [ 1.0099 -0.4266 -0.4266]
# Scores: [ 0.1567 -1.5496]
# Sigmoid terms: [0.4609 0.1751]
# Gradient: [-0.1429  0.0323  0.0323]
# Updated weights: [ 1.0813 -0.4427 -0.4427]
# Test Point 1 Probability (class -1): 0.1174 (Correct)
# Test Point 2 Probability (class +1): 0.6544 (Correct)
#
# === Iteration 15 ===
# Current weights: [ 1.0813 -0.4427 -0.4427]
# Scores: [ 0.1959 -1.575 ]
# Sigmoid terms: [0.4512 0.1715]
# Gradient: [-0.1398  0.0317  0.0317]
# Updated weights: [ 1.1512 -0.4585 -0.4585]
# Test Point 1 Probability (class -1): 0.1132 (Correct)
# Test Point 2 Probability (class +1): 0.6666 (Correct)
# === Iteration 16 ===
# Current weights: [ 1.1512 -0.4585 -0.4585]
# Scores: [ 0.2341 -1.6001]
# Sigmoid terms: [0.4417 0.168 ]
# Gradient: [-0.1369  0.0311  0.0311]
# Updated weights: [ 1.2197 -0.4741 -0.4741]
# Test Point 1 Probability (class -1): 0.1092 (Correct)
# Test Point 2 Probability (class +1): 0.6782 (Correct)
#
# === Iteration 17 ===
# Current weights: [ 1.2197 -0.4741 -0.4741]
# Scores: [ 0.2715 -1.6249]
# Sigmoid terms: [0.4325 0.1645]
# Gradient: [-0.134   0.0305  0.0305]
# Updated weights: [ 1.2867 -0.4894 -0.4894]
# Test Point 1 Probability (class -1): 0.1054 (Correct)
# Test Point 2 Probability (class +1): 0.6894 (Correct)
# === Iteration 18 ===
# Current weights: [ 1.2867 -0.4894 -0.4894]
# Scores: [ 0.308  -1.6495]
# Sigmoid terms: [0.4236 0.1612]
# Gradient: [-0.1312  0.03    0.03  ]
# Updated weights: [ 1.3523 -0.5043 -0.5043]
# Test Point 1 Probability (class -1): 0.1017 (Correct)
# Test Point 2 Probability (class +1): 0.7001 (Correct)
#
# === Iteration 19 ===
# Current weights: [ 1.3523 -0.5043 -0.5043]
# Scores: [ 0.3436 -1.6738]
# Sigmoid terms: [0.4149 0.1579]
# Gradient: [-0.1285  0.0294  0.0294]
# Updated weights: [ 1.4165 -0.519  -0.519 ]
# Test Point 1 Probability (class -1): 0.0983 (Correct)
# Test Point 2 Probability (class +1): 0.7104 (Correct)
# === Iteration 20 ===
# Current weights: [ 1.4165 -0.519  -0.519 ]
# Scores: [ 0.3784 -1.6978]
# Sigmoid terms: [0.4065 0.1548]
# Gradient: [-0.1259  0.0289  0.0289]
# Updated weights: [ 1.4795 -0.5335 -0.5335]
# Test Point 1 Probability (class -1): 0.0949 (Correct)
# Test Point 2 Probability (class +1): 0.7203 (Correct)
